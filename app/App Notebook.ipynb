# %%
os.chdir('./scrapy_folder')
from boxoffice.spiders.imdb import ImdbSpider
from boxoffice.spiders.boxoffice import BoxOfficeSpider

from twisted.internet import reactor, defer
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging


@defer.inlineCallbacks
def crawl():
    yield runner.crawl(BoxOfficeSpider)
    yield runner.crawl(ImdbSpider)
    reactor.stop()

configure_logging()
runner = CrawlerRunner()
crawl()
reactor.run() # the script will block here until the last crawl call is finished
# Out:
# 2022-01-29 17:18:25 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2022-01-29 17:18:25 [scrapy.extensions.telnet] INFO: Telnet Password: aa237b32b9da65a3
# 2022-01-29 17:18:25 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-01-29 17:18:25 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-01-29 17:18:25 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-01-29 17:18:25 [scrapy.middleware] INFO: Enabled item pipelines:
# ['boxoffice.pipelines.BoxofficePipeline', 'boxoffice.pipelines.MongoPipeline']
# 2022-01-29 17:18:25 [scrapy.core.engine] INFO: Spider opened
# 2022-01-29 17:18:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-29 17:18:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-01-29 17:18:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boxofficemojo.com/weekend/by-year/2022/?area=FR> (referer: None)
# 2022-01-29 17:18:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3> (referer: https://www.boxofficemojo.com/weekend/by-year/2022/?area=FR)
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -49.5,
#  'cinemasDiff': 46,
#  'distributor': 'Sony Pictures Releasing',
#  'nbCinemas': 938,
#  'nbWeeks': 4,
#  'rank': 1,
#  'rank_last_week': 1,
#  'recettes': 3682759,
#  'recettes_cumul': 49195066,
#  'releaseID': 'rl841253633',
#  'title': 'Spider-Man: No Way Home',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -65.2,
#  'cinemasDiff': 122,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 923,
#  'nbWeeks': 3,
#  'rank': 2,
#  'rank_last_week': 2,
#  'recettes': 1608640,
#  'recettes_cumul': 16097737,
#  'releaseID': 'rl3710354177',
#  'title': 'Sing 2',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'StudioCanal UK',
#  'nbCinemas': 538,
#  'nbWeeks': 1,
#  'rank': 3,
#  'rank_last_week': nan,
#  'recettes': 1501218,
#  'recettes_cumul': 1501218,
#  'releaseID': 'rl539525889',
#  'title': 'Waiting for Bojangles',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -34.5,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 503,
#  'nbWeeks': 2,
#  'rank': 4,
#  'rank_last_week': 3,
#  'recettes': 1376354,
#  'recettes_cumul': 4124600,
#  'releaseID': 'rl472285953',
#  'title': "The King's Man",
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'SND Films',
#  'nbCinemas': 432,
#  'nbWeeks': 1,
#  'rank': 5,
#  'rank_last_week': nan,
#  'recettes': 824713,
#  'recettes_cumul': 824713,
#  'releaseID': 'rl858358529',
#  'title': 'The 355',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -47.6,
#  'cinemasDiff': -24,
#  'distributor': 'Kino Swiat',
#  'nbCinemas': 616,
#  'nbWeeks': 3,
#  'rank': 6,
#  'rank_last_week': 6,
#  'recettes': 816600,
#  'recettes_cumul': 6788618,
#  'releaseID': 'rl489063169',
#  'title': 'The Matrix Resurrections',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 184,
#  'nbWeeks': 1,
#  'rank': 7,
#  'rank_last_week': nan,
#  'recettes': 755803,
#  'recettes_cumul': 755803,
#  'releaseID': 'rl556303105',
#  'title': 'Licorice Pizza',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -60.9,
#  'cinemasDiff': -309,
#  'distributor': 'Inconnu',
#  'nbCinemas': 598,
#  'nbWeeks': 5,
#  'rank': 8,
#  'rank_last_week': 4,
#  'recettes': 741152,
#  'recettes_cumul': 18532549,
#  'releaseID': 'rl3609363201',
#  'title': 'Les Tuche 4',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -60.0,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 555,
#  'nbWeeks': 7,
#  'rank': 9,
#  'rank_last_week': 5,
#  'recettes': 695530,
#  'recettes_cumul': 20418746,
#  'releaseID': 'rl4146168577',
#  'title': 'Encanto',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -48.3,
#  'cinemasDiff': 29,
#  'distributor': 'Apollo Films',
#  'nbCinemas': 463,
#  'nbWeeks': 2,
#  'rank': 10,
#  'rank_last_week': 7,
#  'recettes': 521934,
#  'recettes_cumul': 1745537,
#  'releaseID': 'rl505840385',
#  'title': 'Le test',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -12.1,
#  'cinemasDiff': 78,
#  'distributor': 'Haut et Court',
#  'nbCinemas': 526,
#  'nbWeeks': 4,
#  'rank': 11,
#  'rank_last_week': 10,
#  'recettes': 500006,
#  'recettes_cumul': 2953324,
#  'releaseID': 'rl3844375297',
#  'title': 'The Velvet Queen',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -44.2,
#  'cinemasDiff': 13,
#  'distributor': 'UGC Distribution',
#  'nbCinemas': 512,
#  'nbWeeks': 4,
#  'rank': 12,
#  'rank_last_week': 8,
#  'recettes': 465956,
#  'recettes_cumul': 4401666,
#  'releaseID': 'rl3810820865',
#  'title': 'Mes très chers enfants',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Ad Vitam Distribution',
#  'nbCinemas': 185,
#  'nbWeeks': 1,
#  'rank': 13,
#  'rank_last_week': nan,
#  'recettes': 329106,
#  'recettes_cumul': 329106,
#  'releaseID': 'rl573080321',
#  'title': 'My Brothers and I',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Diaphana Films',
#  'nbCinemas': 146,
#  'nbWeeks': 1,
#  'rank': 14,
#  'rank_last_week': nan,
#  'recettes': 298500,
#  'recettes_cumul': 298500,
#  'releaseID': 'rl589857537',
#  'title': 'Mali Twist',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -38.2,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 534,
#  'nbWeeks': 5,
#  'rank': 15,
#  'rank_last_week': 11,
#  'recettes': 265994,
#  'recettes_cumul': 4166992,
#  'releaseID': 'rl1176666881',
#  'title': 'West Side Story',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -61.9,
#  'cinemasDiff': -96,
#  'distributor': 'Gaumont',
#  'nbCinemas': 510,
#  'nbWeeks': 4,
#  'rank': 16,
#  'rank_last_week': 9,
#  'recettes': 237154,
#  'recettes_cumul': 3317689,
#  'releaseID': 'rl3827598081',
#  'title': 'Vicky and Her Mystery',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -23.3,
#  'cinemasDiff': 138,
#  'distributor': 'Paname Distribution',
#  'nbCinemas': 358,
#  'nbWeeks': 3,
#  'rank': 17,
#  'rank_last_week': 14,
#  'recettes': 224205,
#  'recettes_cumul': 1173049,
#  'releaseID': 'rl270959361',
#  'title': 'Madeleine Collins',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -47.7,
#  'cinemasDiff': -35,
#  'distributor': 'SND Films',
#  'nbCinemas': 215,
#  'nbWeeks': 8,
#  'rank': 18,
#  'rank_last_week': 13,
#  'recettes': 176292,
#  'recettes_cumul': 12676965,
#  'releaseID': 'rl3944645377',
#  'title': "The Bodin's in the Land of Smile",
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -39.5,
#  'cinemasDiff': nan,
#  'distributor': 'Le Pacte',
#  'nbCinemas': 157,
#  'nbWeeks': 2,
#  'rank': 19,
#  'rank_last_week': 15,
#  'recettes': 158134,
#  'recettes_cumul': 505819,
#  'releaseID': 'rl287736577',
#  'title': 'Deception',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -58.7,
#  'cinemasDiff': 25,
#  'distributor': 'Wild Bunch Distribution',
#  'nbCinemas': 260,
#  'nbWeeks': 2,
#  'rank': 20,
#  'rank_last_week': 12,
#  'recettes': 158079,
#  'recettes_cumul': 598651,
#  'releaseID': 'rl522617601',
#  'title': 'Belle',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -24.2,
#  'cinemasDiff': 85,
#  'distributor': 'Memento Films',
#  'nbCinemas': 325,
#  'nbWeeks': 4,
#  'rank': 21,
#  'rank_last_week': 16,
#  'recettes': 146538,
#  'recettes_cumul': 1339411,
#  'releaseID': 'rl3861152513',
#  'title': 'A Hero',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -24.5,
#  'cinemasDiff': -61,
#  'distributor': 'Inconnu',
#  'nbCinemas': 285,
#  'nbWeeks': 6,
#  'rank': 22,
#  'rank_last_week': 18,
#  'recettes': 142641,
#  'recettes_cumul': 4577494,
#  'releaseID': 'rl521634561',
#  'title': 'Parallel Mothers',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Paramount Pictures International',
#  'nbCinemas': 290,
#  'nbWeeks': 6,
#  'rank': 23,
#  'rank_last_week': nan,
#  'recettes': 141798,
#  'recettes_cumul': 5188976,
#  'releaseID': 'rl4112745217',
#  'title': 'Clifford the Big Red Dog',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -27.1,
#  'cinemasDiff': -43,
#  'distributor': 'Universal Pictures',
#  'nbCinemas': 151,
#  'nbWeeks': 7,
#  'rank': 24,
#  'rank_last_week': 20,
#  'recettes': 127974,
#  'recettes_cumul': 6216963,
#  'releaseID': 'rl4045439745',
#  'title': 'House of Gucci',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -32.8,
#  'cinemasDiff': 27,
#  'distributor': 'Inconnu',
#  'nbCinemas': 116,
#  'nbWeeks': 2,
#  'rank': 25,
#  'rank_last_week': 19,
#  'recettes': 121842,
#  'recettes_cumul': 358953,
#  'releaseID': 'rl304513793',
#  'title': 'The Card Counter',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -25.9,
#  'cinemasDiff': -10,
#  'distributor': 'Warner Bros.',
#  'nbCinemas': 78,
#  'nbWeeks': 6,
#  'rank': 26,
#  'rank_last_week': 22,
#  'recettes': 93694,
#  'recettes_cumul': 2020960,
#  'releaseID': 'rl371426049',
#  'title': 'King Richard',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Gaumont',
#  'nbCinemas': 61,
#  'nbWeeks': 1,
#  'rank': 27,
#  'rank_last_week': nan,
#  'recettes': 87824,
#  'recettes_cumul': 87824,
#  'releaseID': 'rl606634753',
#  'title': 'Rosy',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -53.1,
#  'cinemasDiff': 10,
#  'distributor': 'Inconnu',
#  'nbCinemas': 108,
#  'nbWeeks': 2,
#  'rank': 28,
#  'rank_last_week': 21,
#  'recettes': 74319,
#  'recettes_cumul': 280448,
#  'releaseID': 'rl321291009',
#  'title': 'The Best Years',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -71.3,
#  'cinemasDiff': -165,
#  'distributor': 'Sony Pictures Releasing',
#  'nbCinemas': 132,
#  'nbWeeks': 6,
#  'rank': 29,
#  'rank_last_week': 17,
#  'recettes': 55111,
#  'recettes_cumul': 4967262,
#  'releaseID': 'rl4095968001',
#  'title': 'Ghostbusters: Afterlife',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'UGC Distribution',
#  'nbCinemas': 170,
#  'nbWeeks': 6,
#  'rank': 30,
#  'rank_last_week': nan,
#  'recettes': 47499,
#  'recettes_cumul': 1013530,
#  'releaseID': 'rl4146299649',
#  'title': 'Animal',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -60.8,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 10,
#  'rank': 31,
#  'rank_last_week': 30,
#  'recettes': 7361,
#  'recettes_cumul': 16225906,
#  'releaseID': 'rl320701185',
#  'title': 'Eternals',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -21.1,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 11,
#  'rank': 32,
#  'rank_last_week': 31,
#  'recettes': 2890,
#  'recettes_cumul': 3666637,
#  'releaseID': 'rl286819073',
#  'title': 'The French Dispatch',
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W01/?area=FR&ref_=bo_wey_table_3>
# {'boxDiff': -53.8,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 12,
#  'rank': 33,
#  'rank_last_week': 32,
#  'recettes': 691,
#  'recettes_cumul': 4729253,
#  'releaseID': 'rl555254529',
#  'title': "Ron's Gone Wrong",
#  'week': 1,
#  'week_year': ' 1 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2> (referer: https://www.boxofficemojo.com/weekend/by-year/2022/?area=FR)
# 2022-01-29 17:18:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1> (referer: https://www.boxofficemojo.com/weekend/by-year/2022/?area=FR)
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -39.5,
#  'cinemasDiff': -81,
#  'distributor': 'Sony Pictures Releasing',
#  'nbCinemas': 857,
#  'nbWeeks': 5,
#  'rank': 1,
#  'rank_last_week': 1,
#  'recettes': 2227143,
#  'recettes_cumul': 52122139,
#  'releaseID': 'rl841253633',
#  'title': 'Spider-Man: No Way Home',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Inconnu',
#  'nbCinemas': 610,
#  'nbWeeks': 1,
#  'rank': 2,
#  'rank_last_week': nan,
#  'recettes': 1673935,
#  'recettes_cumul': 1674015,
#  'releaseID': 'rl3643310849',
#  'title': 'Adieu Monsieur Haffmann',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -31.3,
#  'cinemasDiff': 28,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 951,
#  'nbWeeks': 4,
#  'rank': 3,
#  'rank_last_week': 2,
#  'recettes': 1104602,
#  'recettes_cumul': 17399126,
#  'releaseID': 'rl3710354177',
#  'title': 'Sing 2',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -33.9,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 3,
#  'rank': 4,
#  'rank_last_week': 4,
#  'recettes': 909992,
#  'recettes_cumul': 5266927,
#  'releaseID': 'rl472285953',
#  'title': "The King's Man",
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -46.3,
#  'cinemasDiff': 10,
#  'distributor': 'StudioCanal UK',
#  'nbCinemas': 548,
#  'nbWeeks': 2,
#  'rank': 5,
#  'rank_last_week': 3,
#  'recettes': 806047,
#  'recettes_cumul': 2676803,
#  'releaseID': 'rl539525889',
#  'title': 'Waiting for Bojangles',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -33.6,
#  'cinemasDiff': -87,
#  'distributor': 'Sony Pictures Releasing',
#  'nbCinemas': 770,
#  'nbWeeks': 6,
#  'rank': 1,
#  'rank_last_week': 1,
#  'recettes': 1479799,
#  'recettes_cumul': 53557133,
#  'releaseID': 'rl841253633',
#  'title': 'Spider-Man: No Way Home',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -34.7,
#  'cinemasDiff': 65,
#  'distributor': 'Inconnu',
#  'nbCinemas': 675,
#  'nbWeeks': 2,
#  'rank': 2,
#  'rank_last_week': 2,
#  'recettes': 1093644,
#  'recettes_cumul': 3228038,
#  'releaseID': 'rl3643310849',
#  'title': 'Adieu Monsieur Haffmann',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Memento Films',
#  'nbCinemas': 237,
#  'nbWeeks': 1,
#  'rank': 6,
#  'rank_last_week': nan,
#  'recettes': 805272,
#  'recettes_cumul': 805272,
#  'releaseID': 'rl3676865281',
#  'title': 'Between Two Worlds',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -28.7,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 8,
#  'rank': 7,
#  'rank_last_week': 9,
#  'recettes': 496148,
#  'recettes_cumul': 19120131,
#  'releaseID': 'rl4146168577',
#  'title': 'Encanto',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -36.8,
#  'cinemasDiff': 3,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 187,
#  'nbWeeks': 2,
#  'rank': 8,
#  'rank_last_week': 7,
#  'recettes': 477926,
#  'recettes_cumul': 1436029,
#  'releaseID': 'rl556303105',
#  'title': 'Licorice Pizza',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 264,
#  'nbWeeks': 1,
#  'rank': 3,
#  'rank_last_week': nan,
#  'recettes': 946140,
#  'recettes_cumul': 946140,
#  'releaseID': 'rl3643507457',
#  'title': 'Nightmare Alley',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -27.5,
#  'cinemasDiff': -137,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 814,
#  'nbWeeks': 5,
#  'rank': 4,
#  'rank_last_week': 3,
#  'recettes': 801097,
#  'recettes_cumul': 18160200,
#  'releaseID': 'rl3710354177',
#  'title': 'Sing 2',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Miramax',
#  'nbCinemas': 529,
#  'nbWeeks': 1,
#  'rank': 5,
#  'rank_last_week': nan,
#  'recettes': 697141,
#  'recettes_cumul': 697141,
#  'releaseID': 'rl69894913',
#  'title': 'Love Is Better Than Life',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -48.6,
#  'cinemasDiff': -58,
#  'distributor': 'Kino Swiat',
#  'nbCinemas': 558,
#  'nbWeeks': 4,
#  'rank': 9,
#  'rank_last_week': 6,
#  'recettes': 419848,
#  'recettes_cumul': 7394535,
#  'releaseID': 'rl489063169',
#  'title': 'The Matrix Resurrections',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -49.5,
#  'cinemasDiff': -204,
#  'distributor': 'Inconnu',
#  'nbCinemas': 394,
#  'nbWeeks': 6,
#  'rank': 10,
#  'rank_last_week': 8,
#  'recettes': 374100,
#  'recettes_cumul': 19098750,
#  'releaseID': 'rl3609363201',
#  'title': 'Les Tuche 4',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -33.9,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 571,
#  'nbWeeks': 4,
#  'rank': 6,
#  'rank_last_week': 4,
#  'recettes': 601206,
#  'recettes_cumul': 6024118,
#  'releaseID': 'rl472285953',
#  'title': "The King's Man",
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -32.1,
#  'cinemasDiff': nan,
#  'distributor': 'StudioCanal UK',
#  'nbCinemas': 548,
#  'nbWeeks': 3,
#  'rank': 7,
#  'rank_last_week': 5,
#  'recettes': 547556,
#  'recettes_cumul': 3413004,
#  'releaseID': 'rl539525889',
#  'title': 'Waiting for Bojangles',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -34.4,
#  'cinemasDiff': 75,
#  'distributor': 'Memento Films',
#  'nbCinemas': 312,
#  'nbWeeks': 2,
#  'rank': 8,
#  'rank_last_week': 6,
#  'recettes': 528331,
#  'recettes_cumul': 1562983,
#  'releaseID': 'rl3676865281',
#  'title': 'Between Two Worlds',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -29.7,
#  'cinemasDiff': 16,
#  'distributor': 'Haut et Court',
#  'nbCinemas': 542,
#  'nbWeeks': 5,
#  'rank': 11,
#  'rank_last_week': 11,
#  'recettes': 351646,
#  'recettes_cumul': 3464059,
#  'releaseID': 'rl3844375297',
#  'title': 'The Velvet Queen',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -58.4,
#  'cinemasDiff': 28,
#  'distributor': 'SND Films',
#  'nbCinemas': 460,
#  'nbWeeks': 2,
#  'rank': 12,
#  'rank_last_week': 5,
#  'recettes': 343201,
#  'recettes_cumul': 1224993,
#  'releaseID': 'rl858358529',
#  'title': 'The 355',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Le Pacte',
#  'nbCinemas': 270,
#  'nbWeeks': 1,
#  'rank': 13,
#  'rank_last_week': nan,
#  'recettes': 337622,
#  'recettes_cumul': 337622,
#  'releaseID': 'rl3693642497',
#  'title': 'Placés',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'UGC Distribution',
#  'nbCinemas': 361,
#  'nbWeeks': 1,
#  'rank': 9,
#  'rank_last_week': nan,
#  'recettes': 478382,
#  'recettes_cumul': 478382,
#  'releaseID': 'rl86672129',
#  'title': "The Butcher's Daughter",
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -4.9,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': 423,
#  'nbWeeks': 9,
#  'rank': 10,
#  'rank_last_week': 7,
#  'recettes': 471807,
#  'recettes_cumul': 21494783,
#  'releaseID': 'rl4146168577',
#  'title': 'Encanto',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -27.8,
#  'cinemasDiff': 101,
#  'distributor': 'Universal Pictures International (UPI)',
#  'nbCinemas': 288,
#  'nbWeeks': 3,
#  'rank': 11,
#  'rank_last_week': 8,
#  'recettes': 345283,
#  'recettes_cumul': 1902344,
#  'releaseID': 'rl556303105',
#  'title': 'Licorice Pizza',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -48.9,
#  'cinemasDiff': -118,
#  'distributor': 'UGC Distribution',
#  'nbCinemas': 394,
#  'nbWeeks': 5,
#  'rank': 14,
#  'rank_last_week': 12,
#  'recettes': 238192,
#  'recettes_cumul': 4780454,
#  'releaseID': 'rl3810820865',
#  'title': 'Mes très chers enfants',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -54.8,
#  'cinemasDiff': 77,
#  'distributor': 'Apollo Films',
#  'nbCinemas': 540,
#  'nbWeeks': 3,
#  'rank': 15,
#  'rank_last_week': 10,
#  'recettes': 236154,
#  'recettes_cumul': 2101749,
#  'releaseID': 'rl505840385',
#  'title': 'Le test',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -34.4,
#  'cinemasDiff': 44,
#  'distributor': 'Diaphana Films',
#  'nbCinemas': 190,
#  'nbWeeks': 2,
#  'rank': 16,
#  'rank_last_week': 14,
#  'recettes': 195872,
#  'recettes_cumul': 582296,
#  'releaseID': 'rl589857537',
#  'title': 'Mali Twist',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -28.0,
#  'cinemasDiff': -103,
#  'distributor': 'Haut et Court',
#  'nbCinemas': 439,
#  'nbWeeks': 6,
#  'rank': 12,
#  'rank_last_week': 11,
#  'recettes': 253318,
#  'recettes_cumul': 3811684,
#  'releaseID': 'rl3844375297',
#  'title': 'The Velvet Queen',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -38.7,
#  'cinemasDiff': -116,
#  'distributor': 'Inconnu',
#  'nbCinemas': 278,
#  'nbWeeks': 7,
#  'rank': 13,
#  'rank_last_week': 10,
#  'recettes': 229360,
#  'recettes_cumul': 19259766,
#  'releaseID': 'rl3609363201',
#  'title': 'Les Tuche 4',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -50.4,
#  'cinemasDiff': -211,
#  'distributor': 'Kino Swiat',
#  'nbCinemas': 347,
#  'nbWeeks': 5,
#  'rank': 14,
#  'rank_last_week': 9,
#  'recettes': 208404,
#  'recettes_cumul': 7636695,
#  'releaseID': 'rl489063169',
#  'title': 'The Matrix Resurrections',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -46.2,
#  'cinemasDiff': 41,
#  'distributor': 'Ad Vitam Distribution',
#  'nbCinemas': 226,
#  'nbWeeks': 2,
#  'rank': 17,
#  'rank_last_week': 13,
#  'recettes': 177086,
#  'recettes_cumul': 592886,
#  'releaseID': 'rl573080321',
#  'title': 'My Brothers and I',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -45.9,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 6,
#  'rank': 18,
#  'rank_last_week': 15,
#  'recettes': 143941,
#  'recettes_cumul': 4292948,
#  'releaseID': 'rl1176666881',
#  'title': 'West Side Story',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Jour2Fête',
#  'nbCinemas': 79,
#  'nbWeeks': 1,
#  'rank': 19,
#  'rank_last_week': nan,
#  'recettes': 133152,
#  'recettes_cumul': 133152,
#  'releaseID': 'rl3710419713',
#  'title': 'Jane by Charlotte',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -41.4,
#  'cinemasDiff': nan,
#  'distributor': 'Le Pacte',
#  'nbCinemas': 270,
#  'nbWeeks': 2,
#  'rank': 15,
#  'rank_last_week': 13,
#  'recettes': 197938,
#  'recettes_cumul': 623854,
#  'releaseID': 'rl3693642497',
#  'title': 'Placés',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -44.8,
#  'cinemasDiff': -38,
#  'distributor': 'SND Films',
#  'nbCinemas': 422,
#  'nbWeeks': 3,
#  'rank': 16,
#  'rank_last_week': 12,
#  'recettes': 189504,
#  'recettes_cumul': 1615929,
#  'releaseID': 'rl858358529',
#  'title': 'The 355',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -51.1,
#  'cinemasDiff': -20,
#  'distributor': 'Paname Distribution',
#  'nbCinemas': 338,
#  'nbWeeks': 4,
#  'rank': 20,
#  'rank_last_week': 17,
#  'recettes': 109643,
#  'recettes_cumul': 1364667,
#  'releaseID': 'rl270959361',
#  'title': 'Madeleine Collins',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -44.7,
#  'cinemasDiff': nan,
#  'distributor': 'SND Films',
#  'nbCinemas': 215,
#  'nbWeeks': 9,
#  'rank': 21,
#  'rank_last_week': 18,
#  'recettes': 97433,
#  'recettes_cumul': 12872253,
#  'releaseID': 'rl3944645377',
#  'title': "The Bodin's in the Land of Smile",
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -44.7,
#  'cinemasDiff': -23,
#  'distributor': 'Memento Films',
#  'nbCinemas': 302,
#  'nbWeeks': 5,
#  'rank': 22,
#  'rank_last_week': 21,
#  'recettes': 80963,
#  'recettes_cumul': 1480554,
#  'releaseID': 'rl3861152513',
#  'title': 'A Hero',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'KMBO',
#  'nbCinemas': 123,
#  'nbWeeks': 1,
#  'rank': 17,
#  'rank_last_week': nan,
#  'recettes': 184938,
#  'recettes_cumul': 184938,
#  'releaseID': 'rl103449345',
#  'title': 'Persian Lessons',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Gébéka Films',
#  'nbCinemas': 133,
#  'nbWeeks': 1,
#  'rank': 18,
#  'rank_last_week': nan,
#  'recettes': 160115,
#  'recettes_cumul': 160115,
#  'releaseID': 'rl120226561',
#  'title': 'Lynx',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'N/A',
#  'nbCinemas': 81,
#  'nbWeeks': 1,
#  'rank': 19,
#  'rank_last_week': nan,
#  'recettes': 152245,
#  'recettes_cumul': 152245,
#  'releaseID': 'rl2016051969',
#  'title': 'The Chef',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -48.9,
#  'cinemasDiff': -4,
#  'distributor': 'Wild Bunch Distribution',
#  'nbCinemas': 256,
#  'nbWeeks': 3,
#  'rank': 23,
#  'rank_last_week': 20,
#  'recettes': 80828,
#  'recettes_cumul': 716105,
#  'releaseID': 'rl522617601',
#  'title': 'Belle',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -37.2,
#  'cinemasDiff': 43,
#  'distributor': 'Inconnu',
#  'nbCinemas': 159,
#  'nbWeeks': 3,
#  'rank': 24,
#  'rank_last_week': 25,
#  'recettes': 76513,
#  'recettes_cumul': 472659,
#  'releaseID': 'rl304513793',
#  'title': 'The Card Counter',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -57.8,
#  'cinemasDiff': 147,
#  'distributor': 'Le Pacte',
#  'nbCinemas': 304,
#  'nbWeeks': 3,
#  'rank': 25,
#  'rank_last_week': 19,
#  'recettes': 66724,
#  'recettes_cumul': 617107,
#  'releaseID': 'rl287736577',
#  'title': 'Deception',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Pyramide Distribution',
#  'nbCinemas': 101,
#  'nbWeeks': 1,
#  'rank': 20,
#  'rank_last_week': nan,
#  'recettes': 140453,
#  'recettes_cumul': 140453,
#  'releaseID': 'rl2032829185',
#  'title': 'Secret Name',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -42.6,
#  'cinemasDiff': -149,
#  'distributor': 'UGC Distribution',
#  'nbCinemas': 245,
#  'nbWeeks': 6,
#  'rank': 21,
#  'rank_last_week': 14,
#  'recettes': 136689,
#  'recettes_cumul': 4948396,
#  'releaseID': 'rl3810820865',
#  'title': 'Mes très chers enfants',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': 92.0,
#  'cinemasDiff': 202,
#  'distributor': 'Inconnu',
#  'nbCinemas': 357,
#  'nbWeeks': 8,
#  'rank': 22,
#  'rank_last_week': 27,
#  'recettes': 122906,
#  'recettes_cumul': 4394116,
#  'releaseID': 'rl521634561',
#  'title': 'Parallel Mothers',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -49.7,
#  'cinemasDiff': -74,
#  'distributor': 'Universal Pictures',
#  'nbCinemas': 77,
#  'nbWeeks': 8,
#  'rank': 26,
#  'rank_last_week': 24,
#  'recettes': 64318,
#  'recettes_cumul': 6344530,
#  'releaseID': 'rl4045439745',
#  'title': 'House of Gucci',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -55.1,
#  'cinemasDiff': -130,
#  'distributor': 'Inconnu',
#  'nbCinemas': 155,
#  'nbWeeks': 7,
#  'rank': 27,
#  'rank_last_week': 22,
#  'recettes': 63999,
#  'recettes_cumul': 4248853,
#  'releaseID': 'rl521634561',
#  'title': 'Parallel Mothers',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -41.2,
#  'cinemasDiff': 11,
#  'distributor': 'Gaumont',
#  'nbCinemas': 72,
#  'nbWeeks': 2,
#  'rank': 28,
#  'rank_last_week': 27,
#  'recettes': 51669,
#  'recettes_cumul': 170246,
#  'releaseID': 'rl606634753',
#  'title': 'Rosy',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -52.3,
#  'cinemasDiff': -150,
#  'distributor': 'Apollo Films',
#  'nbCinemas': 390,
#  'nbWeeks': 4,
#  'rank': 23,
#  'rank_last_week': 15,
#  'recettes': 112572,
#  'recettes_cumul': 2256866,
#  'releaseID': 'rl505840385',
#  'title': 'Le test',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Gaumont',
#  'nbCinemas': 269,
#  'nbWeeks': 14,
#  'rank': 24,
#  'rank_last_week': nan,
#  'recettes': 101200,
#  'recettes_cumul': 6960824,
#  'releaseID': 'rl2803401473',
#  'title': 'Lost Illusions',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -50.4,
#  'cinemasDiff': 11,
#  'distributor': 'Diaphana Films',
#  'nbCinemas': 201,
#  'nbWeeks': 3,
#  'rank': 25,
#  'rank_last_week': 16,
#  'recettes': 97158,
#  'recettes_cumul': 736643,
#  'releaseID': 'rl589857537',
#  'title': 'Mali Twist',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -49.2,
#  'cinemasDiff': -16,
#  'distributor': 'Warner Bros.',
#  'nbCinemas': 62,
#  'nbWeeks': 7,
#  'rank': 29,
#  'rank_last_week': 26,
#  'recettes': 47594,
#  'recettes_cumul': 2098279,
#  'releaseID': 'rl371426049',
#  'title': 'King Richard',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -17.7,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 11,
#  'rank': 30,
#  'rank_last_week': 31,
#  'recettes': 6056,
#  'recettes_cumul': 16234271,
#  'releaseID': 'rl320701185',
#  'title': 'Eternals',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Inconnu',
#  'nbCinemas': 255,
#  'nbWeeks': 14,
#  'rank': 26,
#  'rank_last_week': nan,
#  'recettes': 88336,
#  'recettes_cumul': 804233,
#  'releaseID': 'rl2618852097',
#  'title': 'First Cow',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Wild Bunch Distribution',
#  'nbCinemas': 318,
#  'nbWeeks': 18,
#  'rank': 27,
#  'rank_last_week': nan,
#  'recettes': 84540,
#  'recettes_cumul': 1756552,
#  'releaseID': 'rl2568127233',
#  'title': 'The Summit of the Gods',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -52.6,
#  'cinemasDiff': 38,
#  'distributor': 'Ad Vitam Distribution',
#  'nbCinemas': 264,
#  'nbWeeks': 3,
#  'rank': 28,
#  'rank_last_week': 17,
#  'recettes': 83952,
#  'recettes_cumul': 731749,
#  'releaseID': 'rl573080321',
#  'title': 'My Brothers and I',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': -44.7,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 12,
#  'rank': 31,
#  'rank_last_week': 32,
#  'recettes': 1599,
#  'recettes_cumul': 3669597,
#  'releaseID': 'rl286819073',
#  'title': 'The French Dispatch',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': 91.5,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 13,
#  'rank': 32,
#  'rank_last_week': 33,
#  'recettes': 1323,
#  'recettes_cumul': 4730576,
#  'releaseID': 'rl555254529',
#  'title': "Ron's Gone Wrong",
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W02/?area=FR&ref_=bo_wey_table_2>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 9,
#  'rank': 33,
#  'rank_last_week': nan,
#  'recettes': 8,
#  'recettes_cumul': 920944,
#  'releaseID': 'rl622756609',
#  'title': 'Antlers',
#  'week': 2,
#  'week_year': ' 2 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Memento Films',
#  'nbCinemas': 252,
#  'nbWeeks': 15,
#  'rank': 29,
#  'rank_last_week': nan,
#  'recettes': 80434,
#  'recettes_cumul': 1741133,
#  'releaseID': 'rl538542849',
#  'title': 'The Worst Person in the World',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': nan,
#  'cinemasDiff': nan,
#  'distributor': 'Pyramide Distribution',
#  'nbCinemas': 297,
#  'nbWeeks': 8,
#  'rank': 30,
#  'rank_last_week': nan,
#  'recettes': 79410,
#  'recettes_cumul': 695999,
#  'releaseID': 'rl3928195841',
#  'title': 'There Is No Evil',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -50.4,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 7,
#  'rank': 31,
#  'rank_last_week': 18,
#  'recettes': 71428,
#  'recettes_cumul': 4394658,
#  'releaseID': 'rl1176666881',
#  'title': 'West Side Story',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -35.8,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 12,
#  'rank': 32,
#  'rank_last_week': 30,
#  'recettes': 3886,
#  'recettes_cumul': 16238463,
#  'releaseID': 'rl320701185',
#  'title': 'Eternals',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -11.6,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 14,
#  'rank': 33,
#  'rank_last_week': 32,
#  'recettes': 1169,
#  'recettes_cumul': 4731745,
#  'releaseID': 'rl555254529',
#  'title': "Ron's Gone Wrong",
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boxofficemojo.com/weekend/2022W03/?area=FR&ref_=bo_wey_table_1>
# {'boxDiff': -57.8,
#  'cinemasDiff': nan,
#  'distributor': 'Walt Disney Studios Motion Pictures',
#  'nbCinemas': nan,
#  'nbWeeks': 13,
#  'rank': 34,
#  'rank_last_week': 31,
#  'recettes': 675,
#  'recettes_cumul': 3670597,
#  'releaseID': 'rl286819073',
#  'title': 'The French Dispatch',
#  'week': 3,
#  'week_year': ' 3 - 2022',
#  'year': 2022}
# 2022-01-29 17:18:31 [scrapy.core.engine] INFO: Closing spider (finished)
# ...
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BOTc0ZGQwMTAtNGM5Zi00OGZjLTlmMWMtZDNjN2M3YjNmMmUyXkEyXkFqcGdeQXVyMjI2MDYzNDE@._V1.png',
#                'name': 'Benedict Cumberbatch'},
#               {'actorId': 'nm8188622',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTJmMDA1ODUtYWI0NS00MjA4LWFiZjgtOTk1OGQ3MDQ4Mjg4XkEyXkFqcGdeQXVyMTA1MTQ2ODk1._V1.png',
#                'name': 'Jacob Batalon'},
#               {'actorId': 'nm0269463',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNjcwNzg4MjktNDNlMC00M2U1LWJmMjgtZTVkMmI4MDI2MTVmXkEyXkFqcGdeQXVyMjI4MDI0NTM@._V1.png',
#                'name': 'Jon Favreau'},
#               {'actorId': 'nm0004937',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTkyNjY1NDg3NF5BMl5BanBnXkFtZTgwNjA2MTg0MzE@._V1.png',
#                'name': 'Jamie Foxx'},
#               {'actorId': 'nm0000353',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BOWU4MTI2OTctODQ1ZS00MGM1LWJkM2EtODE3MGNkNmIyZDEwXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Willem Dafoe'},
#               {'actorId': 'nm0000547',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTEwNTgzNzgxNzNeQTJeQWpwZ15BbWU3MDQ5NzU1NjM@._V1.png',
#                'name': 'Alfred Molina'},
#               {'actorId': 'nm0938950',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNTNlMjg3NWQtZmJlNS00NGU2LWI5NWMtZDk2MGI1YTI4YTVkXkEyXkFqcGdeQXVyMTgyMzY5MTk@._V1.png',
#                'name': 'Benedict Wong'},
#               {'actorId': 'nm1727825',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjgyNGIyZmMtMTFlYy00OWE5LWE2Y2QtYjhhOGU0NzM4YzliXkEyXkFqcGdeQXVyMzk0NzA4MDc@._V1.png',
#                'name': 'Tony Revolori'},
#               {'actorId': 'nm0000673',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTUwMjA3OTc3N15BMl5BanBnXkFtZTcwNTA1MzY1Mw@@._V1.png',
#                'name': 'Marisa Tomei'},
#               {'actorId': 'nm1940449',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjE2MjI2OTk1OV5BMl5BanBnXkFtZTgwNTY1NzM4MDI@._V1.png',
#                'name': 'Andrew Garfield'},
#               {'actorId': 'nm0001497',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTYwMTI5NTM2OF5BMl5BanBnXkFtZTcwODk3MDQ2Mg@@._V1.png',
#                'name': 'Tobey Maguire'},
#               {'actorId': 'nm3886028',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMzhkMTczYWEtOThmYS00MDEyLTgzZjAtODE5YTUwMmJiMjAzXkEyXkFqcGdeQXVyOTE0NjgwMjY@._V1.png',
#                'name': 'Angourie Rice'},
#               {'actorId': 'nm1573892',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNWMwODM2ZmMtZjdkNi00MDFhLTkxYzItMDQzYTkzZDNmNmI0XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Arian Moayed'},
#               {'actorId': 'nm0628420',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BYmVmNjUyNmUtNTIwZC00NGZjLWI5YWEtYmI3YjM3MzhmZWNhXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Paula Newsome'},
#               {'actorId': 'nm2868110',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjI2NzIwNTQ1N15BMl5BanBnXkFtZTgwMTQzNTc4NDE@._V1.png',
#                'name': 'Hannibal Buress'},
#               {'actorId': 'nm0771414',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BYmQ3NDdjNzMtZWIyMC00OWRhLTgzNDYtZDlkMmE4YWY5YTEyXkEyXkFqcGdeQXVyNjc5Mjg0NjU@._V1.png',
#                'name': 'Martin Starr'}],
#  'note': 8.7,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYWEyNTc0ZjUtYzA5ZC00ZWVhLWI5MmUtYzcwMDhiMmNjODQzXkEyXkFqcGdeQXVyODc0OTEyNDU@._V1.png',
#  'recettes_inter': 1694986280,
#  'recettes_totales': 53557133,
#  'releaseDate': 'Dec 15, 2021',
#  'releaseID': 'rl841253633',
#  'resume': 'With Spider-Man&apos;s identity now revealed, Peter asks Doctor '
#            'Strange for help. When a spell goes wrong, dangerous foes from '
#            'other worlds start to appear, forcing Peter to discover what it '
#            'truly means to be Spider-Man.',
#  'runningTime': 148,
#  'title': 'Spider-Man: No Way Home'}
# 2022-01-29 17:18:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt7740510/fullcredits> (referer: https://www.imdb.com/title/tt7740510/?ref_=nv_sr_srsg_0)
# 2022-01-29 17:18:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt7740510/fullcredits>
# {'budget': '$10,619,670',
#  'cast': [{'actorId': 'nm0005392',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMTA4MDM4MzUzNzZeQTJeQWpwZ15BbWU3MDM0NjY4NDM@._V1.png',
#            'name': 'Keri Russell',
#            'role': 'Julia Meadows'},
#           {'actorId': 'nm0687146',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BZTQyMzQzMjEtODVjMS00YzEzLWJjNzItY2I0MWM1YjY3MjZkXkEyXkFqcGdeQXVyMTMxNjMxMjE5._V1.png',
#            'name': 'Jesse Plemons',
#            'role': 'Paul Meadows'},
#           {'actorId': 'nm8864596',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMjNmZWExZGUtOTMwZi00MGM4LTkzMDctYTdiYmFlZmI2OTE2XkEyXkFqcGdeQXVyNzQ2NzM4NzU@._V1.png',
#            'name': 'Jeremy T. Thomas',
#            'role': 'Lucas Weaver'},
#           {'actorId': 'nm0001295',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMTcwMTM3OTQyM15BMl5BanBnXkFtZTcwNzYxNTcyMQ@@._V1.png',
#            'name': 'Graham Greene',
#            'role': 'Warren Stokes'},
#           {'actorId': 'nm2020278',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BNDg4ZWM1YTItZWFmMC00YjRiLWE3MmMtMWZkY2FhZDU3ZDJiXkEyXkFqcGdeQXVyNTY0NTUxOQ@@._V1.png',
#            'name': 'Scott Haze',
#            'role': 'Frank Weaver'},
#           {'actorId': 'nm0168262',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BZWM4MTM5NmUtNDc5NC00ZTQ0LTg3ZWMtYmI5MTJiMDEyMmUyXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#            'name': 'Rory Cochrane',
#            'role': 'Daniel LeCroy'},
#           {'actorId': 'nm0001496',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMTQzMzcxNDYyMl5BMl5BanBnXkFtZTcwMzA5NjQ5MQ@@._V1.png',
#            'name': 'Amy Madigan',
#            'role': 'Principal Ellen Booth'},
#           {'actorId': 'nm9510736',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BYTA2NDY3NzktMzBhOS00NzFlLWJiMmQtNGU0MGI0NWIyYWRhXkEyXkFqcGdeQXVyNjUwMzYwNjU@._V1.png',
#            'name': 'Sawyer Jones',
#            'role': 'Aiden Weaver'},
#           {'actorId': 'nm6813456',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BNDRhMzgyOGEtYmMwZS00ZGRlLWE4NjEtNDBjYjY5MWNiZmIwXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#            'name': 'Cody Davis',
#            'role': 'Clint Owens'},
#           {'actorId': 'nm9463942',
#            'img_link': 'https://m.media-amazon.com/images/S/sash/N1QWYSqAfSJV62Y.png',
#            'name': 'Lyla Marlow',
#            'role': 'Jasmine Drury'},
#           {'actorId': 'nm6105289',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMzgxN2ZiMTgtNzVkYi00MWNkLWExMTUtMDkxMmYwOWU4Zjk1XkEyXkFqcGdeQXVyNDgyNTYxNzU@._V1.png',
#            'name': 'Jesse Downs',
#            'role': 'Harrison Crawford'},
#           {'actorId': 'nm6721990',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMDQ0YWU3NTctZmQ2OC00MzI4LTliNzgtZDE0OTEzMWVkZGU2XkEyXkFqcGdeQXVyMTI3MTg1NDEw._V1.png',
#            'name': 'Arlo Hajdu',
#            'role': 'Arlo Kebbins'},
#           {'actorId': 'nm1141776',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMjE1OTYwMjQ0Ml5BMl5BanBnXkFtZTgwMDA3NDEwMTE@._V1.png',
#            'name': 'Dorian Kingi',
#            'role': 'Antlered Man'},
#           {'actorId': 'nm0469584',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMTg4ODYyNzIyMl5BMl5BanBnXkFtZTcwOTAzNjg0Nw@@._V1.png',
#            'name': 'Ken Kramer',
#            'role': 'Dr. Gerald Ferguson'},
#           {'actorId': 'nm0852256',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMjJjMmZlOTctZWQ2ZC00MDE1LWJjMmMtODgyYjU5NmExZDhhXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#            'name': 'Dendrie Taylor',
#            'role': 'Carol Reynolds'},
#           {'actorId': 'nm0002902',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BNmUxYmM1ODctODA3Mi00YzBjLWFlNWItNjE0MjY5NWY3MWI0XkEyXkFqcGdeQXVyMjczMjgxOA@@._V1.png',
#            'name': 'Andy Thompson',
#            'role': 'Father Meadows'},
#           {'actorId': 'nm0731197',
#            'img_link': 'https://m.media-amazon.com/images/S/sash/N1QWYSqAfSJV62Y.png',
#            'name': 'Jake T. Roberts',
#            'role': 'Forensic Officer'},
#           {'actorId': 'nm0203728',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BYTg0MGVhOTItMWI1NC00MzU0LWExYmEtZTFlMTdlOTYxOWNkXkEyXkFqcGdeQXVyMjE5Mzk2MjA@._V1.png',
#            'name': 'Glynis Davies',
#            'role': 'Nurse Lorraine Byrd'},
#           {'actorId': 'nm1002664',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMzEwODcwMDAyM15BMl5BanBnXkFtZTcwNTUxNjc1Ng@@._V1.png',
#            'name': 'Michael Eklund',
#            'role': 'Kenny Glass'},
#           {'actorId': 'nm5065803',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BY2QwOTliZTgtNWEwZC00ZTQ2LTljOTItYWZjMDEzMjlkZjA5XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#            'name': 'Charmaine Wilson',
#            'role': 'Market Cashier'},
#           {'actorId': 'nm0106319',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BMTA4MjUwNzk2ODBeQTJeQWpwZ15BbWU3MDUwODMwMDg@._V1.png',
#            'name': 'Jay Brazeau',
#            'role': 'Dr. Francis'},
#           {'actorId': 'nm9252944',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BOWY0NzQyNTYtMjllYi00OTEzLWEwOWQtMGNlMDEzMzkwYTc3XkEyXkFqcGdeQXVyODAxNzcwMDQ@._V1.png',
#            'name': 'Katelyn Peterson',
#            'role': 'Young Julia'},
#           {'actorId': 'nm5290511',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BYzU1MDA1MjUtYTQzZi00ZDc2LWFiMjAtZGY3MDZkNmEwMTU1XkEyXkFqcGdeQXVyNzMxNTU1MDk@._V1.png',
#            'name': 'Lisa Cromarty',
#            'role': 'Ojibwei Narrator'},
#           {'actorId': 'nm4454799',
#            'img_link': 'https://m.media-amazon.com/images/M/MV5BZmU2OTQ2MDctNjQwMC00YTVjLWJlYTgtODM2OTU5YjcxMjllXkEyXkFqcGdeQXVyNDUxMDA5OTI@._V1.png',
#            'name': 'Emily Delahunty',
#            'role': 'Evie'}],
#  'country_origin': None,
#  'director': 'Scott Cooper',
#  'genres': ['Drama', 'Horror', 'Mystery'],
#  'mainCast': [{'actorId': 'nm0005392',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTA4MDM4MzUzNzZeQTJeQWpwZ15BbWU3MDM0NjY4NDM@._V1.png',
#                'name': 'Keri Russell'},
#               {'actorId': 'nm0687146',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BZTQyMzQzMjEtODVjMS00YzEzLWJjNzItY2I0MWM1YjY3MjZkXkEyXkFqcGdeQXVyMTMxNjMxMjE5._V1.png',
#                'name': 'Jesse Plemons'},
#               {'actorId': 'nm8864596',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjNmZWExZGUtOTMwZi00MGM4LTkzMDctYTdiYmFlZmI2OTE2XkEyXkFqcGdeQXVyNzQ2NzM4NzU@._V1.png',
#                'name': 'Jeremy T. Thomas'},
#               {'actorId': 'nm0001295',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTcwMTM3OTQyM15BMl5BanBnXkFtZTcwNzYxNTcyMQ@@._V1.png',
#                'name': 'Graham Greene'},
#               {'actorId': 'nm2020278',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNDg4ZWM1YTItZWFmMC00YjRiLWE3MmMtMWZkY2FhZDU3ZDJiXkEyXkFqcGdeQXVyNTY0NTUxOQ@@._V1.png',
#                'name': 'Scott Haze'},
#               {'actorId': 'nm0168262',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BZWM4MTM5NmUtNDc5NC00ZTQ0LTg3ZWMtYmI5MTJiMDEyMmUyXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Rory Cochrane'},
#               {'actorId': 'nm0001496',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTQzMzcxNDYyMl5BMl5BanBnXkFtZTcwMzA5NjQ5MQ@@._V1.png',
#                'name': 'Amy Madigan'},
#               {'actorId': 'nm9510736',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BYTA2NDY3NzktMzBhOS00NzFlLWJiMmQtNGU0MGI0NWIyYWRhXkEyXkFqcGdeQXVyNjUwMzYwNjU@._V1.png',
#                'name': 'Sawyer Jones'},
#               {'actorId': 'nm6813456',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNDRhMzgyOGEtYmMwZS00ZGRlLWE4NjEtNDBjYjY5MWNiZmIwXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Cody Davis'},
#               {'actorId': 'nm9463942',
#                'img_link': 'https://m.media-amazon.com/images/S/sash/N1QWYSqAfSJV62Y.png',
#                'name': 'Lyla Marlow'},
#               {'actorId': 'nm6105289',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMzgxN2ZiMTgtNzVkYi00MWNkLWExMTUtMDkxMmYwOWU4Zjk1XkEyXkFqcGdeQXVyNDgyNTYxNzU@._V1.png',
#                'name': 'Jesse Downs'},
#               {'actorId': 'nm6721990',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMDQ0YWU3NTctZmQ2OC00MzI4LTliNzgtZDE0OTEzMWVkZGU2XkEyXkFqcGdeQXVyMTI3MTg1NDEw._V1.png',
#                'name': 'Arlo Hajdu'},
#               {'actorId': 'nm1141776',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjE1OTYwMjQ0Ml5BMl5BanBnXkFtZTgwMDA3NDEwMTE@._V1.png',
#                'name': 'Dorian Kingi'},
#               {'actorId': 'nm0469584',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMTg4ODYyNzIyMl5BMl5BanBnXkFtZTcwOTAzNjg0Nw@@._V1.png',
#                'name': 'Ken Kramer'},
#               {'actorId': 'nm0852256',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BMjJjMmZlOTctZWQ2ZC00MDE1LWJjMmMtODgyYjU5NmExZDhhXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1.png',
#                'name': 'Dendrie Taylor'},
#               {'actorId': 'nm0002902',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BNmUxYmM1ODctODA3Mi00YzBjLWFlNWItNjE0MjY5NWY3MWI0XkEyXkFqcGdeQXVyMjczMjgxOA@@._V1.png',
#                'name': 'Andy Thompson'},
#               {'actorId': 'nm0731197',
#                'img_link': 'https://m.media-amazon.com/images/S/sash/N1QWYSqAfSJV62Y.png',
#                'name': 'Jake T. Roberts'},
#               {'actorId': 'nm0203728',
#                'img_link': 'https://m.media-amazon.com/images/M/MV5BYTg0MGVhOTItMWI1NC00MzU0LWExYmEtZTFlMTdlOTYxOWNkXkEyXkFqcGdeQXVyMjE5Mzk2MjA@._V1.png',
#                'name': 'Glynis Davies'}],
#  'note': 5.9,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1OTY2NzItNWVkYi00ODRjLTg5OTItMDMxN2U2NmEwYjhlXkEyXkFqcGdeQXVyMTI0NTE1Njg4._V1.png',
#  'recettes_inter': 18538150,
#  'recettes_totales': 920944,
#  'releaseDate': 'Nov 17, 2021',
#  'releaseID': 'rl622756609',
#  'resume': 'In an isolated Oregon town, a middle-school teacher and her '
#            'sheriff brother become embroiled with her enigmatic student, whose '
#            'dark secrets lead to terrifying encounters with an ancestral '
#            'creature.',
#  'runningTime': 99,
#  'title': 'Affamés'}
# 2022-01-29 17:18:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-01-29 17:18:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 63081,
#  'downloader/request_count': 150,
#  'downloader/request_method_count/GET': 150,
#  'downloader/response_bytes': 21973673,
#  'downloader/response_count': 150,
#  'downloader/response_status_count/200': 150,
#  'elapsed_time_seconds': 15.18268,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 1, 29, 17, 18, 46, 478009),
#  'httpcompression/response_bytes': 42011159,
#  'httpcompression/response_count': 100,
#  'item_scraped_count': 50,
#  'log_count/DEBUG': 200,
#  'log_count/INFO': 10,
#  'memusage/max': 134987776,
#  'memusage/startup': 134987776,
#  'request_depth_max': 2,
#  'response_received_count': 150,
#  'scheduler/dequeued': 150,
#  'scheduler/dequeued/memory': 150,
#  'scheduler/enqueued': 150,
#  'scheduler/enqueued/memory': 150,
#  'start_time': datetime.datetime(2022, 1, 29, 17, 18, 31, 295329)}
# 2022-01-29 17:18:46 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import sys
print(sys.path)
import os
os.chdir('/home/dev/code/app/scrapy_folder')
# Out:
# ['/home/dev/code/app', '/usr/local/lib/python38.zip', '/usr/local/lib/python3.8', '/usr/local/lib/python3.8/lib-dynload', '', '/root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages']

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'App Notebook.ipynb', 'app.py', 'Dockerfile', 'forms.py', 'mongo_data', 'requirements.txt', 'scrapy_folder', 'static', 'templates', '__init__.py', '__pycache__']

# %%
import os

# %%
# !python scrapy_folder/launchSpider.py

# %%
execfile("../scrapy/launchSpider.py")
